# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
from imageai.Detection.Custom import DetectionModelTrainer

trainer = DetectionModelTrainer()
trainer.setModelTypeAsYOLOv3()
trainer.setDataDirectory(data_directory="maconha")
trainer.setTrainConfig(object_names_array=["maconha"], batch_size=4, num_experiments=200, train_from_pretrained_model="pretrained-yolov3.h5")
trainer.trainModel()
# Out:
# Using TensorFlow backend.
# Generating anchor boxes for training images and annotation...
# Average IOU for 9 anchors: 0.74
# Anchor Boxes generated.
# Detection configuration saved in  maconha\json\detection_config.json
# Training on: 	['maconha']
# Training with Batch Size:  4
# Number of Experiments:  200
# WARNING:tensorflow:From D:\Usuarios\spi112884\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From D:\Usuarios\spi112884\Anaconda3\lib\site-packages\imageai\Detection\Custom\yolo.py:24: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# ...

# %%
metrics = trainer.evaluateModel(model_path="maconha/models", json_path="maconha/json/detection_config.json", iou_threshold=0.5, object_threshold=0.3, nms_threshold=0.5)
print(metrics)
# Out:
# Starting Model evaluation....
# Model File:  maconha/models\detection_model-ex-001--loss-0037.869.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.3
# Using Non-Maximum Suppression :  0.5
# maconha: 0.1839
# mAP: 0.1839
# ...
# Model File:  maconha/models\detection_model-ex-002--loss-0015.062.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.3
# Using Non-Maximum Suppression :  0.5
# maconha: 0.1548
# mAP: 0.1548
# ...
# skipping the evaluation of maconha/models\detection_model-ex-003--loss-0011.956.h5 because following exception occurred: cannot convert float infinity to integer
# Model File:  maconha/models\detection_model-ex-004--loss-0011.422.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.3
# Using Non-Maximum Suppression :  0.5
# maconha: 0.4949
# mAP: 0.4949
# ...
# Model File:  maconha/models\detection_model-ex-005--loss-0010.719.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.3
# Using Non-Maximum Suppression :  0.5
# maconha: 0.2487
# mAP: 0.2487
# ...

# %%
from imageai.Detection.Custom import DetectionModelTrainer

trainer = DetectionModelTrainer()
trainer.setModelTypeAsYOLOv3()
trainer.setDataDirectory(data_directory="maconha")
metrics = trainer.evaluateModel(model_path="maconha/models2", json_path="maconha/json/detection_config.json", iou_threshold=0.5, object_threshold=0.3, nms_threshold=0.5)
print(metrics)
# Out:
# Starting Model evaluation....

# %%
from imageai.Detection.Custom import DetectionModelTrainer

trainer = DetectionModelTrainer()
trainer.setModelTypeAsYOLOv3()
trainer.setDataDirectory(data_directory="maconha")
metrics = trainer.evaluateModel(model_path="maconha/models2", json_path="maconha/json/detection_config.json", iou_threshold=0.5, object_threshold=0.3, nms_threshold=0.5)
print(metrics)
# Out:
# Starting Model evaluation....
# skipping the evaluation of maconha/models2\detection_model-ex-003--loss-0011.956.h5 because following exception occurred: cannot convert float infinity to integer
# Model File:  maconha/models2\detection_model-ex-094--loss-0003.650.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.3
# Using Non-Maximum Suppression :  0.5
# maconha: 0.6392
# mAP: 0.6392
# ...
# [{'model_file': 'maconha/models2\\detection_model-ex-094--loss-0003.650.h5', 'using_iou': 0.5, 'using_object_threshold': 0.3, 'using_non_maximum_suppression': 0.5, 'average_precision': {'maconha': 0.6391755309560362}, 'map': 0.6391755309560362}]

# %%
from imageai.Detection.Custom import CustomObjectDetection


import glob, os
cwd = os.getcwd()



os.chdir(cwd)

print (cwd)


detector = CustomObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath("detection_model_ex_11.h5")
detector.setJsonPath("detection_config.json")
detector.loadModel()

for file in glob.glob("*.jpg"):
    detections = detector.detectObjectsFromImage(input_image=file, output_image_path= "detected_"+file, display_object_name = False)
# Out:
# D:\Usuarios\spi112884\Desktop\teste_imageai_headset\maconha\validation\images

# %%
import glob, os
cwd = os.getcwd()
print (cwd)




os.chdir(cwd+"\images")
for file in glob.glob("*.jpg"):
    print(file)
# Out:
# D:\Usuarios\spi112884\Desktop\teste_imageai_headset\maconha\validation
# maconha_061.jpg
# maconha_062.jpg
# maconha_063.jpg
# maconha_064.jpg
# maconha_066.jpg
# maconha_067.jpg
# maconha_068.jpg
# maconha_069.jpg
# maconha_070.jpg
# maconha_073.jpg
# maconha_074.jpg
# maconha_075.jpg
# maconha_076.jpg
# maconha_077.jpg
# maconha_078.jpg
# maconha_079.png
# maconha_080.jpeg
# maconha_081.jpg
# maconha_082.jpg
# maconha_084.jpg
# maconha_085.jpg
# maconha_086.jpg
# maconha_087.jpg
# maconha_089.jpg
# maconha_090.jpg
# maconha_091.jpg
# maconha_092.jpg
# maconha_093.jpg
# maconha_095.jpg
# maconha_096.jpg
# maconha_099.jpg
# maconha_100.jpeg
# maconha_101.jpg
# maconha_103.jpg
# maconha_104.jpeg
# maconha_105.jpg
# maconha_106.jpg
# maconha_107.jpg
# maconha_108.jpg
# maconha_109.jpg
# maconha_110.jpg
# maconha_111.jpg
# maconha_113.jpg
# maconha_114.jpg
# maconha_115.jpg
# maconha_116.jpg
# maconha_117.jpg
# maconha_118.jpeg
# maconha_119.jpg
# maconha_120.jpg
# maconha_121.jpg
# ...
